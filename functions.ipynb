# %% [markdown]
# 1.  What is the difference between a function and a method in Python?
#   - * A function is a block of code that is defined using the def keyword or the lambda keyword and is not associated with an object (though it can be used on objects).
#         * A method is a function that is associated with an object. It is defined inside a class and is called on an instance (object) of that class
#
# 2. Explain the concept of function arguments and parameters in Python.
#   - In python, functions are defined to perform some specific task when we define them we passs some values or variable in them.
#       * when we pass values it is called arguments.
#       * when we pass variables it is called parameters.
#
# 3. What are the different ways to define and call a function in Python?
#   - There are various ways to define the function in python.
#     a.) We can define function using 'def' keyword
#     b.) We can also define function by passing default argument in functions.
#     c.) We can also define using lambda (anonymous function)
#   - We can also call function in various ways
#     a.) We can call functions by passing values in order known as positional arguments.
#     b.) It is also being called by keyword argument by matching arguments by name not position.
#   There are several other ways also to call or define a function.
#
# 4. What is the purpose of the `return` statement in a Python function?
#   - The return statement is used to return the result back to the caller on completion of the task. It can return multiple values at a time and it is also used to exit the function early even if there is more code afterward.
# 5. What are iterators in Python and how do they differ from iterables?
#   - An iterator is a object that repressents the stream of a data and returns the next data at the  demand using `next()` function.
#       Whereas an iterable is the object over which the iterator iterates using `iter()` function.
# 6. Explain the concept of generators in Python and how they are defined?
#   - Concept of generator is very similar to the function just the slight difference is that in function we use `return()` fuction which returns all values in one go where as in "GENERATORS" we use `yield()` function which returns one value at a time using `next()`.
#            def square(x):
#               for i in x:
#                  yield i**2
#            num=[1,2,3,4,5]
#            squre= square(num)
#            for r in s:
#               print(r)
# 7. What are the advantages of using generators over regular functions?
#   - The advantage of using generator over regular functions are:
#     a) It returns values one by one isntead of at one go .
#     b) Since, it returns memory one by one the memory usage is less compared to normal function.
#     c) Generators are great for building data pipelines, where each generator processes data and passes it to the next stage.
#     d)  generators yield results one at a time, they can be significantly faster when you don’t need all the data at once.
# 8.  What is a lambda function in Python and when is it typically used?
#   - Lambda function is a small one line function defined using `lambda` keyword. It can have any number of argumengts and it must have a single expresssion.
#       Typically, it is used in short term situation where we need a function just once and don't want to define it by `def`.
#          It is also used with `map()` and `filter()`
# 9. Explain the purpose and usage of the `map()` function in Python?
#   - `map()` is a built in function in python used to apply a function to each item of the iterables.
#    Main purpose of the `map()` is to process each item of a iterable without using explicit loops.It is a oncise and readable way to apply function over all items.
# 10.  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#   - `map()` is used to apply function to the items of the iterables .
#   - `reduce()` applies the  function cumulatively to the items in tge iterable reducing the iterable to a single object.
#   - `filter()` is used to filter out the elemet for which the function returns false and returns an iterator of the filtered items.

# %% [markdown]
# ![question11.jpg](data:image/jpeg;base64,...)

# %%
# 1.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
num=[1,2,3,4,5,6,7,8,9]
def even_sum(x):
  sum=0
  for i in x:
    if i%2==0:
      sum=sum+i
  return sum
print("The sum of even numbers in the list is :",even_sum(num))
# Out:
# The sum of even numbers in the list is : 20

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string
string="pwskills"
def rev_str(s):
  return s[::-1]
rev_str(string)
# Out:
# 'sllikswp'

# %%
# 3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_list(sq):
  new_list=[]
  for i in sq:
    new_list.append(i**2)
  return new_list

num_list=[23,45,32,12,31,78]
print("The updated list with the sqaure of the elements is:",square_list(num_list))
# Out:
# The updated list with the sqaure of the elements is: [529, 2025, 1024, 144, 961, 6084]

# %%
# 4.  Write a Python function that checks if a given number is prime or not from 1 to 200
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False

    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

num = int(input("Enter a number: "))
if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number: 7
# 7 is a prime number.

# %%
# 5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a

n_terms = int(input("Enter number of terms: "))
fib = Fibonacci(n_terms)

for num in fib:
    print(num, end=' ')
# Out:
# Enter number of terms: 6
# 0 1 1 1 2 3

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent
def powers_of_two(max_exponent):
    for exp in range(max_exponent + 1):
        yield 2 ** exp


max_exp = int(input("Enter the maximum exponent: "))
for value in powers_of_two(max_exp):
    print(value, end=' ')
# Out:
# Enter the maximum exponent: 3
# 1 2 4 8

# %%
#7.  Implement a generator function that reads a file line by line and yields each line as a string
def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()  # .strip() removes newline characters

# Example usage:
file_name = 'example.txt'  # Replace with your actual file path

for line in read_file_line_by_line(file_name):
    print(line)

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
# Example list of tuples
data = [(1, 5), (3, 2), (4, 9), (2, 1)]

# Sort using lambda based on the second element
sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)
# Out:
# [(2, 1), (3, 2), (1, 5), (4, 9)]

# %%
#9.  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
# List of temperatures in Celsius
celsius_temps = [0, 20, 37, 100]

# Conversion function
c_to_f = lambda c: (c * 9/5) + 32

# Use map to apply the conversion
fahrenheit_temps = list(map(c_to_f, celsius_temps))

# Display the result
print("Fahrenheit temperatures:", fahrenheit_temps)
# Out:
# Fahrenheit temperatures: [32.0, 68.0, 98.6, 212.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

def remove_vowels(s):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, s))

# Example usage
input_str = input("Enter a string: ")
result = remove_vowels(input_str)
print("String without vowels:", result)
# Out:
# Enter a string: hello
# String without vowels: hll

# %%
''' Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €. '''

orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Use map and lambda to calculate the order total and apply the discount rule
result = list(map(lambda x: (x[0], x[2] * x[3] + 10) if x[2] * x[3] < 100 else (x[0], x[2] * x[3]), orders))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
